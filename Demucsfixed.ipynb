# %% [markdown]
# <a href="https://colab.research.google.com/github/powering-gaming/Demucs-modified/blob/main/Demucsfixed.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Demucs
#
# Demucs is a music source seperation model from Facebook. Provide it a song and it will seperate the track into individual files containing drums, bass, vocals, and "other".
#
# [Github Repo](https://github.com/facebookresearch/demucs)

# %%
# !pip install demucs

# %%
# !pip install torchcodec

# %% [markdown]
# Upload your file to Colab, then copy the path below:

# %%
# !python -m demucs.separate /path/to/wav/file

# %% [markdown]
# Turn the folder with the .wav files into a zip.
# Below, change the '/content/test/' with the path of the folder.
# Don't forget to keep the quotation marks ''
# Do the same for the output_filename.

# %%
import shutil
dir_name = '/content/test/'
output_filename = 'test'
shutil.make_archive(output_filename, 'zip', dir_name)
# Out:
# '/content/duvetrussian.zip'

# %% [markdown]
# Delete the folder and/or zip file with the separated tracks of the song

# %%
import shutil
import os

file_to_delete = 'my_dummy_file.txt'
folder_path = '/content/separated'

if os.path.exists(folder_path):
    shutil.rmtree(folder_path)
    print(f"Folder '{folder_path}' and its contents have been deleted.")
else:
    print(f"Folder '{folder_path}' does not exist.")

if os.path.exists(file_to_delete):
    os.remove(file_to_delete)
    print(f"File '{file_to_delete}' has been deleted successfully.")
else:
    print(f"File '{file_to_delete}' does not exist.")
